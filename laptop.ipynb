# %%
import pandas as pd

# %%
df =pd.read_csv( 'laptopPrice.csv')

# %%
df =pd.read_csv(r"C:\Users\chand\OneDrive\Desktop\Data science\data-science-ai-and-ml\projects\laptop\laptopPrice.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().unique()
# Out:
# array([False])

# %%
df.duplicated().nunique()
# Out:
# 1

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     802.000000          802.00000         802.000000
# mean    76625.543641          299.84414          36.089776
# std     45232.984422         1001.78442         118.313553
# min     16990.000000            0.00000           0.000000
# 25%     45990.000000            0.00000           0.000000
# 50%     63990.000000           17.00000           2.000000
# 75%     89525.000000          140.25000          18.000000
# max    441990.000000        15279.00000        1947.000000

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.head(10)
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
df.tail(10)
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 813    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 814    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 815    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 816    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 817    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# ...

# %%
df.brand
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 802, dtype: object

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
df.Price
# Out:
# 0       34649
# 1       38999
# 2       39999
# 3       69990
# 4       26990
#         ...
# 818    135990
# 819    144990
# 820    149990
# 821    142990
# 822     57490
# Name: Price, Length: 802, dtype: int64

# %%
df['brand']
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 802, dtype: object

# %%
df['processor_name']
# Out:
# 0           Core i3
# 1           Core i3
# 2           Core i3
# 3           Core i5
# 4      Celeron Dual
#            ...
# 818         Ryzen 9
# 819         Ryzen 9
# 820         Ryzen 9
# 821         Ryzen 9
# 822         Ryzen 5
# Name: processor_name, Length: 802, dtype: object

# %%
df['brand'].value_counts()
# Out:
# brand
# ASUS      243
# DELL      149
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      23
# Avita       6
# Name: count, dtype: int64

# %%
df['ram_type'].value_counts()
# Out:
# ram_type
# DDR4       690
# LPDDR4X     56
# LPDDR4      27
# LPDDR3      14
# DDR5         8
# DDR3         7
# Name: count, dtype: int64

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
df['brand'].nunique()
# Out:
# 8

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.shape
# Out:
# (802, 19)

# %%
df[df['brand'] =='Lenovo']
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 8    Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 17   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 19   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 771  Lenovo             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 784  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 787  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 795  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
lenovo_df =df[df['brand']== 'Lenovo']

# %%
lenovo_df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 8    Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 17   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 19   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 771  Lenovo             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 784  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 787  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 795  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
lenovo_df[lenovo_df['Price'] <= 45000]
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 17   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 19   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 25   Lenovo           Intel        Core i3            10th   8 GB     DDR4
# 34   Lenovo           Intel        Core i3            11th   8 GB     DDR4
# 35   Lenovo           Intel        Core i3            10th   8 GB     DDR4
# 38   Lenovo           Intel        Core i3            11th   8 GB     DDR4
# 43   Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 46   Lenovo           Intel        Core i3            10th   8 GB     DDR4
# 51   Lenovo           Intel        Core i3            11th   8 GB     DDR4
# ...

# %%
lenovo_df[lenovo_df['processor_brand']== 'AMD']
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 659  Lenovo             AMD        Ryzen 3   Not Available   4 GB     DDR4
# 669  Lenovo             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 670  Lenovo             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 675  Lenovo             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 677  Lenovo             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 681  Lenovo             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 700  Lenovo             AMD        Ryzen 5   Not Available   4 GB  LPDDR4X
# 703  Lenovo             AMD        Ryzen 5   Not Available   4 GB     DDR4
# 709  Lenovo             AMD        Ryzen 5   Not Available   4 GB     DDR4
# 719  Lenovo             AMD        Ryzen 5   Not Available   4 GB     DDR4
# 727  Lenovo             AMD        Ryzen 5   Not Available   4 GB  LPDDR4X
# ...

# %%
lenovo_df=df[(df['brand'] == 'lenovo')&
   (df["processor_brand"] == 'AMD')&
   (df['ssd']=='512G')&
   (df['Price']<=45000)]

# %%
lenovo_df
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
df.rename(columns= {'ram_gb':'ram'},inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn   ram ram_type  \
# 0      ASUS           Intel        Core i3            10th  4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th  4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th  4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th  8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available  4 GB     DDR4
# ..      ...             ...            ...             ...   ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th  8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df.select_dtypes(include='object')
# Out:
#       brand processor_brand processor_name processor_gnrtn   ram ram_type  \
# 0      ASUS           Intel        Core i3            10th  4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th  4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th  4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th  8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available  4 GB     DDR4
# ..      ...             ...            ...             ...   ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th  8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
num = df.select_dtypes(exclude='object')

# %%
num
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]

# %%
print(num.columns)
# Out:
# Index(['Price', 'Number of Ratings', 'Number of Reviews'], dtype='object')

# %%
num.head()
# Out:
#    Price  Number of Ratings  Number of Reviews
# 0  34649                  3                  0
# 1  38999                 65                  5
# 2  39999                  8                  1
# 3  69990                  0                  0
# 4  26990                  0                  0

# %%
num['Price'].unique()
# Out:
# array([ 34649,  38999,  39999,  69990,  26990,  22990,  21990,  58799,
#         49999,  59990,  93700,  72990,  17490,  35990,  56490,  65390,
#         31999,  32490,  31799,  29890,  23990,  32955,  46200,  34429,
#         37990,  33980,  39990,  39490,  53990,  38990,  37890,  41990,
#         45990,  42490,  36990,  38940,  42990,  49990,  41490,  38490,
#         44990,  36490,  38970,  44900,  44427,  40200,  40990,  71999,
#         41998,  39998,  48490,  44376,  43900,  46690,  43990,  48500,
#         48990,  23490,  54238,  51990,  43970,  54990,  41250,  60790,
#         45650,  45490,  38799,  69267,  51649,  47990,  44890,  50990,
#         48900,  41790,  57999,  45930,  55490,  32890,  42190,  43690,
#         43800,  34990,  38900,  40890,  39790,  35590,  33990,  43400,
#         24990,  40750,  43000,  38000,  49279,  41500,  36999,  42900,
#         21490,  41480,  32990,  38680,  40390,  20490,  44490,  41890,
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

df['Number of Ratings'] =le.fit_transform(df['Number of Ratings'])

# %%
num
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn   ram ram_type  \
# 0      ASUS           Intel        Core i3            10th  4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th  4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th  4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th  8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available  4 GB     DDR4
# ..      ...             ...            ...             ...   ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th  8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
clean_data =pd.concat([num],axis =1)

# %%
clean_data
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]
